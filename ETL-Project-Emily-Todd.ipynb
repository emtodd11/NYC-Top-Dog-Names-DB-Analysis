# %%
# dependencies

import pandas as pd
from sqlalchemy import create_engine, inspect

# %%
# read raw data csv

csv_file = "NYC_Dog_Licensing_Dataset.csv"
all_dog_data = pd.read_csv(csv_file)
all_dog_data.head(10)
# Out:
#    RowNumber AnimalName AnimalGender        AnimalBirthMonth  \
# 0        533    BONITA             F  05/01/2013 12:00:00 AM
# 1        548      ROCKY            M  05/01/2014 12:00:00 AM
# 2        622      BULLY            M  07/01/2010 12:00:00 AM
# 3        633      COCO             M  02/01/2005 12:00:00 AM
# 4        655       SKI             F  09/01/2012 12:00:00 AM
# 5        872      CHASE            M  11/01/2013 12:00:00 AM
# 6        874     CHEWY             M  09/01/2014 12:00:00 AM
# 7        875      CHASE            M  08/01/2008 12:00:00 AM
# 8        893      MILEY            F  07/01/2008 12:00:00 AM
# 9        919      KENZI            F  05/01/2010 12:00:00 AM
#
#                             BreedName Borough  ZipCode  CommunityDistrict  \
# 0                             Unknown  Queens  11435.0              412.0
# 1       Labrador Retriever Crossbreed  Queens  11691.0              414.0
# 2  American Pit Bull Terrier/Pit Bull  Queens  11419.0              410.0
# 3                  Labrador Retriever  Queens  11692.0              414.0
# 4  American Pit Bull Terrier/Pit Bull  Queens  11691.0              414.0
# 5                            Shih Tzu  Queens  11692.0              414.0
# 6                            Shih Tzu  Queens  11694.0              414.0
# 7                  Labrador Retriever  Queens  11691.0              414.0
# 8                               Boxer  Queens  11419.0              410.0
# 9                Schnauzer, Miniature  Queens  11420.0              410.0
#
#    CensusTract2010   NTA  CityCouncilDistrict  CongressionalDistrict  \
# 0            208.0  QN61                 28.0                    5.0
# 1         100801.0  QN15                 31.0                    5.0
# 2             98.0  QN55                 28.0                    5.0
# 3            964.0  QN12                 31.0                    5.0
# 4         100802.0  QN15                 31.0                    5.0
# 5            964.0  QN12                 31.0                    5.0
# 6          94201.0  QN10                 32.0                    5.0
# 7            992.0  QN12                 31.0                    5.0
# 8          15802.0  QN55                 28.0                    5.0
# 9          84601.0  QN55                 28.0                    5.0
#
#    StateSenatorialDistrict LicenseIssuedDate LicenseExpiredDate
# 0                     10.0        10/24/2014         11/15/2017
# 1                     10.0        10/25/2014         10/25/2019
# 2                     10.0        10/28/2014         09/24/2016
# 3                     10.0        10/29/2014         10/29/2017
# 4                     10.0        10/31/2014         10/31/2019
# 5                     10.0        11/23/2014         11/23/2016
# 6                     10.0        11/24/2014         11/24/2016
# 7                     10.0        11/24/2014         11/25/2017
# 8                     10.0        11/26/2014         01/21/2016
# 9                     10.0        11/27/2014         01/03/2016

# %%
# trim data frame to necessary columns

dog_data_df = all_dog_data[['AnimalName','AnimalGender','BreedName','Borough','ZipCode']]
dog_data_df.head(10)
# Out:
#   AnimalName AnimalGender                           BreedName Borough  ZipCode
# 0    BONITA             F                             Unknown  Queens  11435.0
# 1      ROCKY            M       Labrador Retriever Crossbreed  Queens  11691.0
# 2      BULLY            M  American Pit Bull Terrier/Pit Bull  Queens  11419.0
# 3      COCO             M                  Labrador Retriever  Queens  11692.0
# 4       SKI             F  American Pit Bull Terrier/Pit Bull  Queens  11691.0
# 5      CHASE            M                            Shih Tzu  Queens  11692.0
# 6     CHEWY             M                            Shih Tzu  Queens  11694.0
# 7      CHASE            M                  Labrador Retriever  Queens  11691.0
# 8      MILEY            F                               Boxer  Queens  11419.0
# 9      KENZI            F                Schnauzer, Miniature  Queens  11420.0

# %%
# remove incomplete rows

dog_data_df.count()
# Out:
# AnimalName      121714
# AnimalGender    121948
# BreedName       121948
# Borough         121948
# ZipCode         121948
# dtype: int64

# %%
cleaned_dog_data_df = dog_data_df.dropna(how='any')

# %%
cleaned_dog_data_df.count()
# Out:
# AnimalName      121713
# AnimalGender    121713
# BreedName       121713
# Borough         121713
# ZipCode         121713
# dtype: int64

# %%
# reformat zip code as integer

cleaned_dog_data_df['ZipCode'] = cleaned_dog_data_df['ZipCode'].astype(int)
cleaned_dog_data_df.head(10)
# Out:
# C:\Users\emily\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   AnimalName AnimalGender                           BreedName Borough  ZipCode
# 0    BONITA             F                             Unknown  Queens    11435
# 1      ROCKY            M       Labrador Retriever Crossbreed  Queens    11691
# 2      BULLY            M  American Pit Bull Terrier/Pit Bull  Queens    11419
# 3      COCO             M                  Labrador Retriever  Queens    11692
# 4       SKI             F  American Pit Bull Terrier/Pit Bull  Queens    11691
# 5      CHASE            M                            Shih Tzu  Queens    11692
# 6     CHEWY             M                            Shih Tzu  Queens    11694
# 7      CHASE            M                  Labrador Retriever  Queens    11691
# 8      MILEY            F                               Boxer  Queens    11419
# 9      KENZI            F                Schnauzer, Miniature  Queens    11420

# %%
# connect to postgres to create dog database

engine = create_engine('postgres://postgres:postgres@localhost:5432')
conn = engine.connect()
conn.execute("commit")
conn.execute("drop database if exists dog_db")
conn.execute("commit")
conn.execute("create database dog_db")

# %%
# import dataframe into database table

engine = create_engine('postgres://postgres:postgres@localhost:5432/dog_db')
conn = engine.connect()
cleaned_dog_data_df.to_sql('dog_names', con=conn, if_exists='replace', index=False)

# %%
# check for data

engine.execute('SELECT * FROM dog_names').fetchall()
# Out:
# [('BONITA ', 'F', 'Unknown', 'Queens', 11435),
#  ('ROCKY', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('BULLY', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('COCO ', 'M', 'Labrador Retriever', 'Queens', 11692),
#  ('SKI ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('CHASE', 'M', 'Shih Tzu', 'Queens', 11692),
#  ('CHEWY ', 'M', 'Shih Tzu', 'Queens', 11694),
#  ('CHASE', 'M', 'Labrador Retriever', 'Queens', 11691),
#  ('MILEY', 'F', 'Boxer', 'Queens', 11419),
#  ('KENZI', 'F', 'Schnauzer, Miniature', 'Queens', 11420),
#  ('APOLLO ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11420),
#  ('BELLA ', 'F', 'Yorkshire Terrier', 'Queens', 11434),
#  ('PENELOPE ', 'F', 'Yorkshire Terrier', 'Queens', 11434),
#  ('JERRY', 'M', 'Labrador Retriever', 'Queens', 11436),
#  ('HAZEL', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11434),
#  ('SIMON', 'M', 'Havanese', 'Queens', 11691),
#  ('PRINCESS', 'F', 'Shih Tzu', 'Queens', 11417),
#  ('PEPPER', 'F', 'Shih Tzu', 'Queens', 11417),
#  ('PEBBLES', 'F', 'Yorkshire Terrier', 'Queens', 11417),
#  ('BUDDY', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11692),
#  ('NAME NOT PROVIDED', 'F', 'Chihuahua', 'Queens', 11420),
#  ('CODY ', 'M', 'Lhasa Apso', 'Queens', 11420),
#  ('CHAMP', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11420),
#  ('J.D', 'M', 'Jack Russell Terrier', 'Queens', 11434),
#  ('TIGGER', 'M', 'Jack Russell Terrier', 'Queens', 11694),
#  ('KUSH ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11422),
#  ('PATCHES', 'F', 'Bulldog', 'Queens', 11691),
#  ('LUNA', 'F', 'Yorkshire Terrier', 'Queens', 11418),
#  ('FUDGE ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Brooklyn', 11692),
#  ('CRAZY ', 'F', 'American Staffordshire Terrier ', 'Queens', 11436),
#  ('NAME NOT PROVIDED', 'F', 'Shih Tzu', 'Queens', 11419),
#  ('NAME NOT PROVIDED', 'F', 'Unknown', 'Queens', 11418),
#  ('NAME NOT PROVIDED', 'F', 'Puggle', 'Queens', 11418),
#  ('ACE ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11416),
#  ('FRECKLES', 'F', 'English Cocker Spaniel', 'Queens', 11418),
#  ('LILY', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11419),
#  ('UNKNOWN', 'M', 'Cocker Spaniel', 'Queens', 11436),
#  ('MISSY ', 'F', 'Yorkshire Terrier', 'Queens', 11434),
#  ('BENJI ', 'M', 'West Highland White Terrier', 'Queens', 11419),
#  ('TORIS', 'M', 'Chihuahua', 'Queens', 11434),
#  ('ROCKY', 'M', 'Staffordshire Bull Terrier', 'Queens', 11419),
#  ('MATIS', 'F', 'Poodle', 'Queens', 11434),
#  ('TINKERBELL ', 'F', 'Shih Tzu', 'Queens', 11417),
#  ('ARI', 'F', 'Pomeranian', 'Queens', 11434),
#  ('NAME NOT PROVIDED', 'M', 'Bull Dog, French', 'Queens', 11422),
#  ('BELLA ', 'F', 'Maltese', 'Queens', 11420),
#  ('JAZZIE ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('NAME NOT PROVIDED', 'M', 'Yorkshire Terrier', 'Queens', 11691),
#  ('OREO', 'M', 'Shih Tzu', 'Queens', 11419),
#  ('SKIPPY', 'M', 'Unknown', 'Queens', 11420),
#  ('UNKNOWN', 'F', 'Cairn Terrier', 'Queens', 11434),
#  ('BINX', 'M', 'Unknown', 'Queens', 11691),
#  ('BIG ', 'F', 'Miniature Pinscher', 'Queens', 11692),
#  ('STAR', 'F', 'Poodle', 'Brooklyn', 11693),
#  ('PINKY', 'F', 'Maltese', 'Queens', 11418),
#  ('NAME NOT PROVIDED', 'M', 'Chihuahua', 'Queens', 11434),
#  ('NAME NOT PROVIDED', 'M', 'Unknown', 'Queens', 11692),
#  ('SMOKEY', 'M', 'Unknown', 'Queens', 11691),
#  ('TOBY', 'M', 'Yorkshire Terrier', 'Queens', 11436),
#  ('JEWEL', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('COURAGE', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11691),
#  ('POPO ', 'M', 'Chihuahua', 'Queens', 11418),
#  ('NAME NOT PROVIDED', 'M', 'Unknown', 'Queens', 11691),
#  ('OLLIVER ', 'M', 'Pekingese', 'Queens', 11420),
#  ('NAME NOT PROVIDED', 'F', 'Unknown', 'Queens', 11435),
#  ('NAME NOT PROVIDED', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('TUFFY', 'F', 'Chow Chow', 'Queens', 11434),
#  ('BROOKLYN', 'F', 'Maltese', 'Queens', 11436),
#  ('UNKNOWN', 'M', 'Unknown', 'Queens', 11416),
#  ('UNKNOWN', 'F', 'Unknown', 'Queens', 11418),
#  ('JORDAN', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('SASHA', 'F', 'Yorkshire Terrier', 'Queens', 11420),
#  ('CHAMP', 'M', 'Pomeranian', 'Queens', 11418),
#  ('XANDY', 'F', 'German Shepherd Dog', 'Queens', 11420),
#  ('NAME NOT PROVIDED', 'M', 'Boxer', 'Queens', 11419),
#  ('NAME NOT PROVIDED', 'M', 'Beagle', 'Queens', 11420),
#  ('SWAGGER', 'F', 'Jack Russell Terrier', 'Queens', 11434),
#  ('CHAMP ', 'M', 'Pomeranian', 'Queens', 11418),
#  ('SPARKY', 'M', 'Unknown', 'Queens', 11418),
#  ('OREO', 'M', 'Shih Tzu', 'Queens', 11436),
#  ('BABY', 'F', 'Unknown', 'Queens', 11691),
#  ('NAME NOT PROVIDED', 'M', 'Jack Russell Terrier', 'Queens', 11420),
#  ('CHARLIE ', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('SEAMUS', 'M', 'Unknown', 'Queens', 11417),
#  ('RICKY', 'M', 'Schnauzer, Standard', 'Queens', 11416),
#  ('HERSHEY', 'F', 'Chihuahua', 'Queens', 11434),
#  ('BLUE', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11420),
#  ('NALA ', 'F', 'Boxer', 'Queens', 11418),
#  ('EMILY ', 'F', 'Beagle', 'Queens', 11420),
#  ('TODD', 'M', 'German Shepherd Dog', 'Queens', 11419),
#  ('MAX', 'M', 'Unknown', 'Queens', 11420),
#  ('JAZZ ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11433),
#  ('BUDDY ', 'M', 'Unknown', 'Queens', 11692),
#  ('DOZER', 'M', 'Unknown', 'Queens', 11420),
#  ('MICKEY', 'M', 'Unknown', 'Queens', 11419),
#  ('KASHMA', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('COKEY', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11420),
#  ('TUNCHII', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('BLUE', 'M', 'Siberian Husky', 'Queens', 11420),
#  ('MARLEY', 'M', 'Rottweiler', 'Queens', 11434),
#  ('NIKKO ', 'M', 'Doberman Pinscher', 'Queens', 11420),
#  ('TEA ', 'F', 'Chihuahua', 'Queens', 11436),
#  ('UNKNOWN', 'F', 'Dachshund', 'Queens', 11416),
#  ('UNKNOWN', 'F', 'Unknown', 'Queens', 11419),
#  ('DANGER', 'M', 'Akita Crossbreed', 'Queens', 11413),
#  ('SOPHIE', 'F', 'Shih Tzu', 'Queens', 11420),
#  ('GINGER ', 'F', 'Shih Tzu', 'Queens', 11419),
#  ('NAME NOT PROVIDED', 'F', 'German Shepherd Dog', 'Queens', 11419),
#  ('DIPSEY ', 'F', 'Toy Fox Terrier', 'Queens', 11436),
#  ('NICKY', 'M', 'Silky Terrier', 'Queens', 11691),
#  ('UNKNOWN', 'F', 'Yorkshire Terrier', 'Queens', 11434),
#  ('BRUCE ', 'M', 'Miniature Pinscher', 'Queens', 11691),
#  ('KATIE', 'F', 'Unknown', 'Queens', 11418),
#  ('VILLIAN', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11434),
#  ('ROCKY', 'M', 'Papillon', 'Queens', 11422),
#  ('MILES', 'M', 'Yorkshire Terrier', 'Queens', 11692),
#  ('POODAH ', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('PINKY ', 'F', 'Shih Tzu', 'Queens', 11434),
#  ('BLUE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11433),
#  ('SOFIE', 'F', 'Shiba Inu', 'Queens', 11691),
#  ('CODY ', 'M', 'Maltese', 'Queens', 11434),
#  ('BENJI ', 'F', 'Maltese', 'Queens', 11434),
#  ('SHADOW', 'M', 'Poodle, Toy', 'Queens', 11436),
#  ('STITCH ', 'M', 'Unknown', 'Queens', 11419),
#  ('APPA', 'M', 'Schnauzer, Miniature', 'Queens', 11420),
#  ('CHAZZ', 'M', 'Maltese', 'Queens', 11413),
#  ('ZEUS ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11433),
#  ('KING', 'M', 'Maltese', 'Queens', 11422),
#  ('BAILEY ', 'M', 'Dachshund, Long Haired Miniature', 'Queens', 11434),
#  ('COBBY', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('JONNEY', 'M', 'Unknown', 'Queens', 11419),
#  ('LADY', 'F', 'Pomeranian', 'Queens', 11436),
#  ('LITTLE ', 'M', 'Cocker Spaniel', 'Queens', 11691),
#  ('UNKNOWN', 'M', 'Yorkshire Terrier', 'Queens', 11419),
#  ('MAX', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11434),
#  ('RAFA', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('MARLEY', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('PETEY', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11420),
#  ('EAZY', 'M', 'Yorkshire Terrier', 'Queens', 11422),
#  ('UNKNOWN', 'M', 'Australian Silky Terrier', 'Queens', 11419),
#  ('PEPPER', 'F', 'Beagle', 'Queens', 11418),
#  ('WILLIE', 'M', 'Maltese', 'Queens', 11693),
#  ('MAYA ', 'F', 'Shih Tzu', 'Queens', 11420),
#  ('LUCKY', 'M', 'Chihuahua', 'Queens', 11691),
#  ('MUGSY', 'M', 'American Staffordshire Terrier ', 'Queens', 11692),
#  ('MILO', 'M', 'Miniature Pinscher', 'Queens', 11422),
#  ('BLUE', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11419),
#  ('KOBA', 'M', 'German Shepherd Dog', 'Queens', 11416),
#  ('DANE', 'M', 'Poodle Crossbreed', 'Queens', 11422),
#  ('HARRY ', 'M', 'Jack Russell Terrier', 'Queens', 11691),
#  ('SPARKY', 'M', 'Unknown', 'Queens', 11694),
#  ('JACK ', 'M', 'German Shepherd Dog', 'Queens', 11416),
#  ('CHLOE', 'F', 'Unknown', 'Queens', 11694),
#  ('CJ', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('POPPY ', 'F', 'Chihuahua', 'Queens', 11693),
#  ('PILLOW ', 'M', 'Shih Tzu', 'Queens', 11693),
#  ('BELLA', 'F', 'Yorkshire Terrier', 'Queens', 11420),
#  ('PUGEY', 'F', 'Pug', 'Queens', 11693),
#  ('CHUBBY', 'M', 'Poodle, Toy', 'Queens', 11420),
#  ('ACE', 'M', 'Poodle', 'Queens', 11694),
#  ('TRUCKDOGG ', 'M', 'Boston Terrier', 'Queens', 11435),
#  ('PUCCIO', 'M', 'Doberman Pinscher', 'Queens', 11434),
#  ('NAME NOT PROVIDED', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('KING', 'M', 'Rottweiler', 'Queens', 11434),
#  ('LOLA', 'F', 'Pekingese', 'Queens', 11434),
#  ('NESSA', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11692),
#  ('ZAX ', 'M', 'Cocker Spaniel', 'Queens', 11692),
#  ('ZIANNI ', 'F', 'Cocker Spaniel', 'Queens', 11692),
#  ('ERNIE', 'M', 'Parson Russell Terrier', 'Queens', 11434),
#  ('HUNTER', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11422),
#  ('CEASER', 'M', 'Jack Russell Terrier', 'Queens', 11418),
#  ('UNKNOWN', 'M', 'Unknown', 'Queens', 11420),
#  ('UNKNOWN', 'M', 'Unknown', 'Queens', 11692),
#  ('PIKACHU', 'F', 'Chihuahua', 'Queens', 11434),
#  ('UNKNOWN', 'F', 'Chihuahua', 'Queens', 11418),
#  ('PLISSKEN', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11417),
#  ('MAX', 'M', 'Unknown', 'Queens', 11421),
#  ('DIESEL ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11422),
#  ('TASHA', 'F', 'Rottweiler', 'Queens', 11418),
#  ('MARLOW', 'F', 'Schnauzer, Miniature', 'Queens', 11420),
#  ('DICE ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11691),
#  ('JESSICA', 'F', 'Cavalier King Charles Spaniel', 'Queens', 11416),
#  ('HARLEY', 'F', 'Havanese', 'Queens', 11692),
#  ('MILO', 'M', 'Chihuahua', 'Queens', 11691),
#  ('HAPPY', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('MAUI', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('CEASAR', 'M', 'American Staffordshire Terrier ', 'Queens', 11692),
#  ('ACE', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11434),
#  ('FREEWAY', 'M', 'Welsh Corgi, Pembroke', 'Queens', 11691),
#  ('SPOT ', 'F', 'American Staffordshire Terrier ', 'Queens', 11418),
#  ('BRUNO ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11433),
#  ('BENTLEY', 'M', 'Yorkshire Terrier', 'Queens', 11413),
#  ('DIAMOND', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11433),
#  ('BISCUIT', 'F', 'Shih Tzu', 'Queens', 11420),
#  ('JOEY', 'M', 'Boston Terrier', 'Queens', 11433),
#  ('LEXI', 'F', 'Shih Tzu', 'Queens', 11434),
#  ('CATO', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11433),
#  ('MISAKI', 'F', 'Shiba Inu', 'Queens', 11693),
#  ('DAKOTA', 'F', 'German Shepherd Dog', 'Queens', 11421),
#  ('WHISKEY ', 'M', 'German Shepherd Crossbreed', 'Queens', 11434),
#  ('LOKI', 'M', 'American Staffordshire Terrier ', 'Queens', 11691),
#  ('CHICA ', 'F', 'Unknown', 'Queens', 11418),
#  ('BELLA ', 'F', 'Yorkshire Terrier', 'Queens', 11691),
#  ('RELLIE', 'M', 'Puggle', 'Queens', 11434),
#  ('BELLA', 'F', 'Miniature Pinscher', 'Queens', 11419),
#  ('MINNIE', 'F', 'Labrador Retriever', 'Queens', 11419),
#  ('COOPER', 'M', 'German Shepherd Crossbreed', 'Queens', 11419),
#  ('ZOE', 'F', 'Schnauzer, Miniature', 'Queens', 11418),
#  ('MESKA', 'M', 'Shih Tzu', 'Queens', 11421),
#  ('CHARLIE', 'M', 'Labrador Retriever', 'Queens', 11691),
#  ('SAGE ', 'M', 'Dachshund, Long Haired', 'Queens', 11691),
#  ('BOO ', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('SNOWBALL', 'M', 'Unknown', 'Queens', 11420),
#  ('DARCY', 'F', 'Beagle', 'Queens', 11421),
#  ('HENNEY ', 'F', 'Shar-Pei, Chinese', 'Queens', 11693),
#  ('MAX', 'M', 'Unknown', 'Queens', 11692),
#  ('TOMMY', 'M', 'Labrador Retriever', 'Queens', 11420),
#  ('MAYA', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11692),
#  ('VENUS', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11692),
#  ('FEMI', 'M', 'Shih Tzu', 'Queens', 11692),
#  ('BEAR', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11418),
#  ('PRINCIPIE ', 'M', 'Unknown', 'Queens', 11692),
#  ('JETT', 'M', 'Labrador Retriever', 'Queens', 11417),
#  ('NAME NOT PROVIDED', 'M', 'Unknown', 'Queens', 11420),
#  ('BOOMER', 'M', 'Unknown', 'Queens', 11434),
#  ('ROMEO', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11422),
#  ('ROVER', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('NAME NOT PROVIDED', 'F', 'Chihuahua', 'Queens', 11413),
#  ('DAEMON ', 'M', 'Siberian Husky', 'Queens', 11422),
#  ('BUTCH', 'M', 'Rottweiler', 'Queens', 11418),
#  ('MOLLY ', 'F', 'Golden Retriever', 'Queens', 11416),
#  ('MAX ', 'M', 'Yorkshire Terrier', 'Queens', 11692),
#  ('BLUE', 'M', 'Staffordshire Bull Terrier', 'Queens', 11418),
#  ('UNKNOWN', 'F', 'Unknown', 'Queens', 11420),
#  ('PATTI', 'F', 'Unknown', 'Queens', 11436),
#  ('MIA', 'F', 'Mastiff, Bull', 'Queens', 11435),
#  ('ZEUS ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11433),
#  ('CASEY ', 'M', 'Unknown', 'Queens', 11434),
#  ('ROCKO', 'F', 'Rottweiler', 'Queens', 11435),
#  ('NAME NOT PROVIDED', 'M', 'Chihuahua', 'Queens', 11691),
#  ('TED', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('TOBY', 'M', 'Jack Russell Terrier', 'Queens', 11419),
#  ('JASHUA', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('JACK ', 'M', 'Pug', 'Queens', 11420),
#  ('BROOKLYN', 'M', 'Boxer', 'Queens', 11418),
#  ('SPARKI ', 'M', 'German Shepherd Dog', 'Queens', 11419),
#  ('THOMAS ', 'M', 'Unknown', 'Queens', 11692),
#  ('EMMA', 'F', 'Chesapeake Bay Retriever', 'Queens', 11692),
#  ('TARA', 'F', 'Golden Retriever', 'Queens', 11419),
#  ('PEACHES', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11436),
#  ('PEACHES', 'F', 'Unknown', 'Queens', 11693),
#  ('ANGEL', 'F', 'Yorkshire Terrier', 'Queens', 11413),
#  ('UNKNOWN', 'M', 'Cocker Spaniel', 'Queens', 11422),
#  ('BRUCE', 'M', 'Maltese', 'Queens', 11420),
#  ('TEDDY', 'M', 'Shih Tzu', 'Queens', 11692),
#  ('EMMY', 'F', 'Unknown', 'Queens', 11435),
#  ('PRINCESS ', 'F', 'Unknown', 'QUEENS', 11691),
#  ('TOBY ', 'M', 'Shiba Inu', 'Queens', 11433),
#  ('DELILAH', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11413),
#  ('GIZMO', 'M', 'Pekingese', 'Queens', 11420),
#  ('WATSON', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('ZOE', 'F', 'Unknown', 'QUEENS', 11419),
#  ('CHESTNUT', 'F', 'Unknown', 'Queens', 11434),
#  ('MILO ', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('CAESAR ', 'M', 'Pomeranian', 'Queens', 11434),
#  ('OLLIE', 'M', 'Chihuahua', 'Queens', 11419),
#  ('DINO', 'M', 'Yorkshire Terrier', 'Queens', 11419),
#  ('NAME NOT PROVIDED', 'M', 'Beagle', 'Queens', 11419),
#  ('NEKO', 'M', 'Rottweiler', 'Queens', 11434),
#  ('PUZZLE', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('MISSIE', 'F', 'Yorkshire Terrier', 'Queens', 11419),
#  ('MAXIMO', 'M', 'Labrador Retriever', 'Queens', 11420),
#  ('BAMBAM', 'M', 'Maltipoo', 'Queens', 11692),
#  ('MAXIMUS', 'M', 'Labrador Retriever', 'Queens', 11420),
#  ('TYSON', 'M', 'Chihuahua', 'Queens', 11433),
#  ('BELLE', 'F', 'Beagle', 'Queens', 11420),
#  ('GIZMO', 'M', 'Havanese', 'Queens', 11416),
#  ('WOW ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11692),
#  ('DIESEL', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11418),
#  ('ADRIENNE', 'F', 'Yorkshire Terrier', 'Queens', 11434),
#  ('LUCKY ', 'F', 'Pug', 'Queens', 11691),
#  ('PARIS ', 'F', 'Pug', 'Queens', 11691),
#  ('BUTTONS ', 'M', 'Pug', 'Queens', 11691),
#  ('KRISTIAN ', 'M', 'Pug', 'Queens', 11691),
#  ('JESSI', 'F', 'Rottweiler', 'Queens', 11420),
#  ('SHUG', 'F', 'Rottweiler', 'Queens', 11420),
#  ('JACK', 'M', 'Siberian Husky', 'Queens', 11420),
#  ('KING', 'M', 'American Staffordshire Terrier ', 'Queens', 11420),
#  ('BEAR', 'M', 'Siberian Husky', 'Queens', 11419),
#  ('MOSELEY', 'M', 'Pug', 'Queens', 11691),
#  ('CURLY', 'M', 'Poodle, Miniature', 'Queens', 11691),
#  ('SOCAL', 'M', 'Unknown', 'Queens', 11418),
#  ('ISHAM', 'M', 'Bulldog', 'Queens', 11419),
#  ('VANLENTINO ', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('KOUTURE ', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11433),
#  ('BUDDY', 'M', 'German Shepherd Crossbreed', 'Queens', 11420),
#  ('ENZO', 'M', 'Pomeranian', 'Queens', 11420),
#  ('HARLEY', 'M', 'Pug', 'Queens', 11694),
#  ('PIPPIN', 'M', 'Italian Greyhound', 'Queens', 11418),
#  ('BUMBLE', 'M', 'Poodle, Toy', 'Queens', 11419),
#  ('ASTIN', 'M', 'Bichon Frise', 'Queens', 11418),
#  ('UNKNOWN', 'F', 'Pomeranian', 'Queens', 11692),
#  ('SAM', 'M', 'Rottweiler', 'Queens', 11420),
#  ('VADER', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11435),
#  ('WILLOW', 'M', 'Shih Tzu', 'Queens', 11413),
#  ('TOBY ', 'M', 'Jack Russell Terrier', 'Queens', 11417),
#  ('HUNTER ', 'M', 'Unknown', 'Queens', 11692),
#  ('SPIKE', 'M', 'German Shepherd Dog', 'Queens', 11416),
#  ('GUCCI ', 'M', 'Yorkshire Terrier', 'Queens', 11433),
#  ('PRECIOUS', 'F', 'Yorkshire Terrier', 'Queens', 11691),
#  ('BENTLEY', 'M', 'Maltese', 'Queens', 11436),
#  ('DAISY', 'F', 'Shih Tzu Crossbreed', 'Queens', 11422),
#  ('MR. ', 'M', 'Shih Tzu Crossbreed', 'Queens', 11692),
#  ('LEXI', 'F', 'Unknown', 'Queens', 11418),
#  ('PRINCESS', 'F', 'Shih Tzu', 'Queens', 11691),
#  ('LUCY', 'F', 'Havanese', 'Queens', 11433),
#  ('DIVA ', 'F', 'Rottweiler', 'Queens', 11420),
#  ('RALPH', 'M', 'Labrador Retriever', 'Queens', 11419),
#  ('RAYMOND', 'M', 'Parson Russell Terrier', 'Queens', 11418),
#  ('ROCCO ', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11692),
#  ('JUICY', 'F', 'Yorkshire Terrier', 'Queens', 11434),
#  ('KINGSTON', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11434),
#  ('LITTLE', 'F', 'Shih Tzu', 'Queens', 11691),
#  ('BP', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11436),
#  ('MAX', 'M', 'American Staffordshire Terrier ', 'Queens', 11419),
#  ('MAGGIE ', 'F', 'Unknown', 'Queens', 11419),
#  ('CHARLIE', 'M', 'Shih Tzu', 'Queens', 11422),
#  ('BUSTER ', 'M', 'Bloodhound', 'Queens', 11419),
#  ('COOKIE', 'F', 'Yorkshire Terrier', 'Queens', 11418),
#  ('NAME NOT PROVIDED', 'M', 'Maltese', 'Queens', 11691),
#  ('MILO', 'M', 'Unknown', 'Queens', 11419),
#  ('UNKNOWN', 'F', 'Yorkshire Terrier', 'Queens', 11419),
#  ('MARBLE', 'M', 'Unknown', 'Queens', 11419),
#  ('CHILLY', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('BUSTER ', 'M', 'Belgian Malinois', 'Queens', 11434),
#  ('PEBBLES', 'F', 'Staffordshire Bull Terrier', 'Queens', 11419),
#  ('NAMASTE', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11435),
#  ('BJ', 'M', 'Labrador Retriever', 'Queens', 11435),
#  ('BIG ', 'M', 'Unknown', 'Queens', 11691),
#  ('SHINE', 'M', 'Jack Russell Terrier', 'Queens', 11692),
#  ('NEGRO ', 'M', 'Poodle, Standard', 'Queens', 11413),
#  ('CUZOW', 'F', 'Chihuahua Crossbreed', 'Queens', 11693),
#  ('BANDIT', 'F', 'French Bulldog', 'Queens', 11418),
#  ('JULIE', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11413),
#  ('SIMBA ', 'M', 'American Staffordshire Terrier ', 'Queens', 11420),
#  ('BOLO ', 'M', 'American Bully', 'Queens', 11691),
#  ('QUTIE ', 'F', 'American Bully', 'Queens', 11691),
#  ('POLLY ', 'F', 'Shih Tzu', 'Queens', 11434),
#  ('BOOGIE ', 'M', 'American Bully', 'Queens', 11691),
#  ('ROCKBOTTOM ', 'M', 'Cane Corso', 'Queens', 11436),
#  ('KIMBELLA', 'F', 'American Bully', 'Queens', 11691),
#  ('SMOKEY', 'M', 'Labrador Retriever', 'Queens', 11419),
#  ('SPARKY', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11419),
#  ('WINSTON ', 'M', 'Unknown', 'Queens', 11691),
#  ('NO', 'M', 'Rat Terrier', 'Queens', 11420),
#  ('MADISON', 'F', 'Australian Cattledog', 'Queens', 11413),
#  ('JUSTIN', 'M', 'Pomeranian', 'Queens', 11434),
#  ('LEXXI', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11694),
#  ('JAGUAR', 'M', 'Unknown', 'Queens', 11691),
#  ('SCOTTIE ', 'M', 'Unknown', 'Queens', 11435),
#  ('ZENA', 'F', 'Unknown', 'Queens', 11436),
#  ('SPIKE ', 'M', 'Bull Terrier', 'QUEENS', 11693),
#  ('LONDON', 'F', 'Shih Tzu', 'Queens', 11691),
#  ('SMILEY', 'M', 'Maltese', 'Queens', 11413),
#  ('LUSTER', 'M', 'Labrador Retriever', 'Queens', 11422),
#  ('MAXIMUS', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11693),
#  ('MARLEY ', 'M', 'Unknown', 'Queens', 11436),
#  ('TOBBY', 'M', 'Shih Tzu', 'Queens', 11691),
#  ('KACY', 'F', 'Maltese', 'Queens', 11418),
#  ('JACK ', 'M', 'Labrador Retriever', 'Queens', 11418),
#  ('KOKO', 'M', 'Maltese', 'Queens', 11418),
#  ('BABY ', 'M', 'Labrador Retriever', 'Queens', 11418),
#  ('KATTY', 'F', 'Chihuahua', 'Queens', 11420),
#  ('OREO/ROSEMARY ', 'F', 'Unknown', 'Queens', 11420),
#  ('DELPHI', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('BIJON', 'M', 'Unknown', 'Queens', 11434),
#  ('MARCKO-POLO', 'M', 'Labrador Retriever', 'Queens', 11692),
#  ('CHARLIE', 'M', 'Schipperke', 'Queens', 11436),
#  ('MISHAQ', 'M', 'Pomeranian', 'Queens', 11436),
#  ('BONEZ', 'M', 'Great Dane', 'Queens', 11434),
#  ('HONEY', 'F', 'Unknown', 'Queens', 11419),
#  ('KING', 'M', 'Labrador Retriever', 'Queens', 11416),
#  ('LUCKY', 'M', 'Unknown', 'Queens', 11420),
#  ('BLUE-GOTTI', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11435),
#  ('UNKNOWN', 'F', 'Shih Tzu', 'Queens', 11416),
#  ('RILEY', 'M', 'Yorkshire Terrier', 'Queens', 11419),
#  ('EDUARDA', 'F', 'Coton de Tulear', 'Queens', 11434),
#  ('BENNY', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('MADISON ', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11692),
#  ('DUTCHESS', 'F', 'German Shepherd Dog', 'Queens', 11692),
#  ('JUSTICES ', 'F', 'Unknown', 'Queens', 11416),
#  ('MAX ', 'M', 'Bichon Frise', 'Queens', 11691),
#  ('UNKNOWN', 'M', 'Maltese', 'Queens', 11422),
#  ('TESA ', 'F', 'Rottweiler', 'Queens', 11434),
#  ('SNICKERS ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11436),
#  ('ACE', 'M', 'Poodle', 'Queens', 11419),
#  ('PEANUTBUTTER', 'F', 'Collie Crossbreed', 'Queens', 11413),
#  ('WHITTEY', 'M', 'Chihuahua', 'Queens', 11413),
#  ('MAXIMUS', 'M', 'Unknown', 'Queens', 11434),
#  ('CINNAMON', 'F', 'Yorkshire Terrier', 'Queens', 11413),
#  ('NALA', 'F', 'Pug', 'Queens', 11420),
#  ('SPARKY', 'M', 'Poodle, Toy', 'Queens', 11435),
#  ('FLUFFY', 'F', 'Poodle', 'Queens', 11434),
#  ('ANGEL ', 'M', 'German Shepherd Dog', 'QUEENS', 11419),
#  ('PEDRO ', 'M', 'Brussels Griffon', 'Queens', 11420),
#  ('BANDIT ', 'M', 'Jack Russell Terrier', 'QUEENS', 11691),
#  ('LEXI', 'F', 'Jack Russell Terrier', 'Queens', 11420),
#  ('KING ', 'M', 'German Shepherd Crossbreed', 'Queens', 11691),
#  ('BUDDY', 'M', 'Unknown', 'Queens', 11422),
#  ('AXE', 'M', 'Yorkshire Terrier', 'Queens', 11422),
#  ('ECLIPSE', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11422),
#  ('SHADOW', 'M', 'Cocker Spaniel', 'Queens', 11418),
#  ('WONDER ', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11435),
#  ('LEILA', 'F', 'Dachshund Smooth Coat Miniature', 'Queens', 11419),
#  ('ROXY ', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11418),
#  ('ISIS', 'F', 'Poodle, Miniature', 'Queens', 11421),
#  ('RILEY', 'M', 'Shiba Inu', 'Queens', 11434),
#  ('ROMEO ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11433),
#  ('OREO', 'M', 'Maltipoo', 'Queens', 11692),
#  ('LOVE ', 'F', 'Yorkshire Terrier', 'Queens', 11691),
#  ('PRINCE', 'M', 'Maltese', 'Queens', 11419),
#  ('JORDAN', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('CESAR', 'M', 'Staffordshire Bull Terrier', 'Queens', 11435),
#  ('DYLAN ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('COCO', 'F', 'Labrador Retriever', 'Queens', 11420),
#  ('LOKI', 'M', 'Miniature Pinscher', 'Queens', 11421),
#  ('TANKER ', 'M', 'Mastiff, Bull', 'Queens', 11420),
#  ('DAISEY', 'F', 'Labrador Retriever', 'Queens', 11691),
#  ('LUCKY', 'M', 'Shih Tzu Crossbreed', 'Queens', 11419),
#  ('VINCE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('BRUNO', 'M', 'Jack Russell Terrier', 'Queens', 11418),
#  ('MADJI', 'F', 'Rottweiler', 'Queens', 11422),
#  ('REX ', 'M', 'Rottweiler', 'Queens', 11694),
#  ('LUCKY', 'M', 'Terrier mix', 'Queens', 11436),
#  ('MILO', 'M', 'Maltese Crossbreed', 'Queens', 11691),
#  ('CHAI ', 'F', 'Chihuahua', 'Queens', 11419),
#  ('NAME NOT PROVIDED', 'M', 'Puggle', 'Queens', 11418),
#  ('MOO ', 'M', 'Yorkshire Terrier', 'Queens', 11436),
#  ('ROCKY', 'M', 'Beagle', 'Queens', 11419),
#  ('SYDNEY', 'F', 'Chinese Shar-Pei', 'Queens', 11419),
#  ('BELLA ', 'F', 'Unknown', 'Queens', 11692),
#  ('SASSY', 'F', 'Yorkshire Terrier Crossbreed', 'Queens', 11436),
#  ('BRUCE', 'M', 'Rottweiler', 'Queens', 11434),
#  ('BRODY', 'F', 'Beagle', 'Queens', 11418),
#  ('APRIL', 'F', 'Shih Tzu Crossbreed', 'Queens', 11692),
#  ('ROCKO', 'M', 'Bull Dog, English', 'Queens', 11436),
#  ('RALPHIE', 'M', 'Unknown', 'Queens', 11417),
#  ('SOFIE', 'F', 'Maltese', 'Queens', 11691),
#  ('SKY', 'F', 'American Eskimo dog', 'Queens', 11436),
#  ('CODY', 'M', 'Yorkshire Terrier', 'Queens', 11435),
#  ('BORIS', 'M', 'Cane Corso', 'Queens', 11436),
#  ('MUFASA', 'M', 'American Bully', 'Queens', 11419),
#  ('MICKEY', 'M', 'Bichon Frise', 'Queens', 11433),
#  ('HERSHIES', 'F', 'Yorkshire Terrier', 'Queens', 11693),
#  ('DEXTER', 'M', 'Shih Tzu', 'Queens', 11419),
#  ('MEMPHIS', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('MARTHA ', 'F', 'American Bully', 'Queens', 11691),
#  ('ELIZABETH ', 'F', 'American Bully', 'Queens', 11691),
#  ('GIZMO ', 'M', 'Chihuahua', 'Queens', 11418),
#  ('SNOOPY ', 'M', 'Unknown', 'Queens', 11422),
#  ('ROMEO', 'M', 'Shih Tzu', 'Queens', 11420),
#  ('ROXY ', 'F', 'Unknown', 'Queens', 11436),
#  ('MADDUX', 'M', 'Unknown', 'Queens', 11419),
#  ('BLUE ', 'M', 'Labrador Retriever', 'Queens', 11420),
#  ('HARLEY', 'M', 'Maltese', 'Queens', 11421),
#  ('UNCLE ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11420),
#  ('BOLO', 'M', 'German Shepherd Dog', 'Queens', 11418),
#  ('MARCO', 'M', 'Yorkshire Terrier', 'Queens', 11436),
#  ('BELLA', 'F', 'German Shepherd Crossbreed', 'Queens', 11420),
#  ('GIZMO ', 'M', 'Yorkshire Terrier', 'Queens', 11692),
#  ('2J', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('SPARKIE', 'M', 'Pekingese', 'Queens', 11420),
#  ('CHIMICHURRI', 'M', 'Border Terrier', 'Queens', 11420),
#  ('RHYMING', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11419),
#  ('ANGEL', 'F', 'Shih Tzu', 'Queens', 11419),
#  ('LUCY', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('CHARLIE ', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('OREO ', 'M', 'Unknown', 'Queens', 11420),
#  ('SKYLER', 'M', 'Maltese', 'Queens', 11692),
#  ('MAX', 'M', 'Dachshund, Wirehaired', 'Queens', 11419),
#  ('BETSY', 'F', 'Pug', 'Queens', 11417),
#  ('LALI', 'F', 'Boxer', 'Queens', 11434),
#  ('SAGE', 'M', 'Newfoundland', 'Queens', 11420),
#  ('JUNIOR', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('CAMY', 'F', 'Pomeranian', 'Queens', 11691),
#  ('FIFI ', 'F', 'Shih Tzu', 'Queens', 11421),
#  ('MISSES ', 'F', 'Unknown', 'Queens', 11433),
#  ('LOKI', 'M', 'Siberian Husky', 'Queens', 11420),
#  ('COOKIE', 'F', 'Boxer', 'Queens', 11418),
#  ('JAKE', 'M', 'Unknown', 'Queens', 11421),
#  ('BOGS', 'M', 'Lhasa Apso', 'Queens', 11421),
#  ('SCAR', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11433),
#  ('BARK ', 'M', 'American Staffordshire Terrier ', 'Queens', 11692),
#  ('STRYKEN ', 'M', 'German Shepherd Dog', 'Queens', 11418),
#  ('PUNKIE', 'M', 'Chihuahua', 'Queens', 11434),
#  ('ROBYN', 'F', 'Cavalier King Charles Spaniel', 'Queens', 11420),
#  ('UNKNOWN', 'M', 'Bichon Frise', 'Queens', 11420),
#  ('LUCKY ', 'M', 'Shih Tzu', 'Queens', 11435),
#  ('CINNAMON', 'F', 'Yorkshire Terrier', 'Queens', 11435),
#  ('JACK', 'M', 'German Shepherd Dog', 'Queens', 11421),
#  ('DIAMOND', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11436),
#  ('NEVEY', 'F', 'Bichon Frise', 'Queens', 11413),
#  ('CINNAMON', 'F', 'Yorkshire Terrier', 'Queens', 11435),
#  ('LEMO', 'M', 'German Shepherd Dog', 'Queens', 11436),
#  ('ZOEY', 'F', 'German Shepherd Dog', 'Queens', 11435),
#  ('PRESLEY ', 'F', 'Beagle', 'Queens', 11420),
#  ('BLACKJACK', 'M', 'German Shepherd Dog', 'Queens', 11435),
#  ('BELLA', 'F', 'Siberian Husky', 'Queens', 11419),
#  ('LAYLA', 'F', 'Yorkshire Terrier', 'Queens', 11693),
#  ('BULLETT ', 'M', 'Miniature Pinscher', 'Queens', 11433),
#  ('JOE ', 'M', 'Yorkshire Terrier', 'Queens', 11422),
#  ('TOBY', 'M', 'Shih Tzu', 'Queens', 11419),
#  ('ROCIO', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11693),
#  ('CODY ', 'M', 'Labrador Retriever', 'Queens', 11418),
#  ('KILLER ', 'M', 'Unknown', 'Queens', 11418),
#  ('KAISER', 'M', 'Miniature Pinscher', 'Queens', 11421),
#  ('MAX', 'M', 'Unknown', 'Queens', 11434),
#  ('BIXBY', 'M', 'Shih Tzu', 'Queens', 11420),
#  ('SUSIE ', 'F', 'Maltipoo', 'Queens', 11436),
#  ('LONDON ', 'F', 'Yorkshire Terrier', 'Queens', 11694),
#  ('ZEUS ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('JOEY', 'M', 'Unknown', 'Queens', 11418),
#  ('RICO', 'M', 'Chihuahua', 'Queens', 11691),
#  ('HONEY ', 'F', 'Unknown', 'Queens', 11421),
#  ('MAXIMUS', 'M', 'Siberian Husky', 'Queens', 11419),
#  ('NAME NOT PROVIDED', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('YU-MY', 'F', 'Shih Tzu', 'Queens', 11435),
#  ('COCOA ', 'F', 'German Shepherd Crossbreed', 'QUEENS', 11436),
#  ('NAME NOT PROVIDED', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('RILEY ', 'M', 'Unknown', 'Queens', 11419),
#  ('TEDDY', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11692),
#  ('ZIG ', 'M', 'Boxer', 'Queens', 11416),
#  ('GINGER', 'F', 'Unknown', 'Queens', 11421),
#  ('CHASE', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11693),
#  ('MISSY ', 'F', 'Golden Retriever', 'Queens', 11693),
#  ('CAINE', 'M', 'Cane Corso', 'Queens', 11434),
#  ('FIOLRY', 'F', 'Poodle, Standard', 'Queens', 11692),
#  ('BENTLEY', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('MINA', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11435),
#  ('KELSEY', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11413),
#  ('MISTY', 'F', 'Rottweiler', 'Queens', 11435),
#  ('PEEWEE', 'M', 'Chihuahua', 'Queens', 11419),
#  ('OREO', 'M', 'Shih Tzu', 'Queens', 11419),
#  ('BEAR', 'M', 'Golden Retriever', 'Queens', 11435),
#  ('NALA', 'F', 'Dogue de Bordeaux', 'Queens', 11413),
#  ('ARIEL', 'F', 'Shih Tzu', 'Queens', 11692),
#  ('GINGER ', 'F', 'Poodle, Toy', 'Queens', 11413),
#  ('PLUTO', 'M', 'Pug', 'Queens', 11418),
#  ('HERCULES ', 'M', 'Cocker Spaniel', 'Queens', 11434),
#  ('CHEWY', 'M', 'Pomeranian', 'Queens', 11692),
#  ('MUNECA', 'F', 'Yorkshire Terrier', 'Queens', 11692),
#  ('AJ', 'M', 'Maltese', 'Queens', 11692),
#  ('SNOWBALL', 'M', 'Poodle, Miniature', 'Queens', 11435),
#  ('HIROSHI', 'M', 'Akita', 'Queens', 11418),
#  ('ALICIA', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11418),
#  ('SPIRIT', 'M', 'Chihuahua Crossbreed', 'Queens', 11691),
#  ('SKITTLEZ ', 'F', 'Pekingese', 'Queens', 11420),
#  ('SNICKERZ ', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('BRUTUS', 'M', 'Papillon', 'Queens', 11418),
#  ('MAXIMILLON ', 'M', 'Shih Tzu', 'Queens', 11692),
#  ('BELLA', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11420),
#  ('LOUIE', 'M', 'Silky Terrier', 'Queens', 11416),
#  ('GOZY', 'M', 'Maltese', 'Queens', 11418),
#  ('CREAM', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('IVORY', 'F', 'Golden Retriever', 'Queens', 11420),
#  ('HAPPY', 'M', 'Shih Tzu', 'Queens', 11418),
#  ('BEAST', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('HUSTLE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11693),
#  ('PEPITO', 'M', 'Cocker Spaniel', 'Queens', 11420),
#  ('BUTTERSCOTCH', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11418),
#  ('NEKO ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('COCO', 'M', 'Boxer', 'Queens', 11421),
#  ('OLIVE', 'F', 'Dachshund Smooth Coat', 'Queens', 11419),
#  ('MOLLY', 'F', 'Rottweiler', 'Queens', 11694),
#  ('BLUE ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('HACK', 'M', 'Pomeranian', 'Queens', 11691),
#  ('MHEKI ', 'M', 'Pug', 'Queens', 11420),
#  ('SNOW', 'M', 'Boxer', 'Queens', 11420),
#  ('PUCHIS', 'F', 'Chihuahua Crossbreed', 'Queens', 11418),
#  ('BUDDY', 'M', 'Poodle, Standard', 'Queens', 11420),
#  ('TYSON ', 'M', 'Unknown', 'Queens', 11433),
#  ('LOBO', 'M', 'Siberian Husky', 'Queens', 11421),
#  ('LYRIC', 'F', 'Bull Dog, French', 'Queens', 11420),
#  ('NAME NOT PROVIDED', 'F', 'Cocker Spaniel', 'Queens', 11419),
#  ('ANGEL', 'F', 'Miniature Pinscher', 'Queens', 11420),
#  ('NAME NOT PROVIDED', 'M', 'Shetland Sheepdog', 'Queens', 11420),
#  ('BENTLEY', 'M', 'Havanese', 'Queens', 11694),
#  ('TUCKER', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'QUEENS', 11433),
#  ('SCOOTER ', 'M', 'Jack Russell Terrier', 'Queens', 11691),
#  ('JUNIOR', 'M', 'Unknown', 'Queens', 11436),
#  ('LUCY', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11419),
#  ('CAPRI', 'M', 'Shih Tzu', 'Queens', 11691),
#  ('TOTO', 'M', 'Havanese', 'Queens', 11418),
#  ('BENNY', 'M', 'Unknown', 'Queens', 11434),
#  ('CHELSEA', 'F', 'American Staffordshire Terrier ', 'Queens', 11693),
#  ('MECCA', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11692),
#  ('ZOE ', 'F', 'Bull Dog, French', 'Queens', 11420),
#  ('DANCER', 'M', 'Brussels Griffon', 'Queens', 11418),
#  ('KISS', 'F', 'Unknown', 'Queens', 11434),
#  ('GOTTI', 'M', 'Unknown', 'Queens', 11420),
#  ('PANDA', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11418),
#  ('TESLA', 'M', 'Beagle', 'Queens', 11419),
#  ('BENTLEY ', 'M', 'Poodle', 'Queens', 11420),
#  ('DITA', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11422),
#  ('GEORGE', 'M', 'Labrador Retriever', 'Queens', 11419),
#  ('LADY ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('CHAMP', 'M', 'Rottweiler', 'Queens', 11435),
#  ('LUKE', 'M', 'Yorkshire Terrier', 'Queens', 11436),
#  ('COCO ', 'M', 'Shih Tzu', 'Queens', 11420),
#  ('SASHA ', 'F', 'Siberian Husky', 'Queens', 11436),
#  ('PEANUT', 'M', 'Unknown', 'Queens', 11434),
#  ('PHOENIX ', 'F', 'German Shepherd Crossbreed', 'Queens', 11421),
#  ('BANDIT ', 'F', 'Unknown', 'Queens', 11419),
#  ('KARA', 'F', 'Siberian Husky', 'Queens', 11418),
#  ('SAMI ', 'F', 'Unknown', 'Queens', 11419),
#  ('TEX', 'M', 'Beagle', 'Queens', 11419),
#  ('LADY ', 'F', 'Maltese Crossbreed', 'Queens', 11420),
#  ('BEAR', 'M', 'Cavalier King Charles Spaniel', 'Queens', 11422),
#  ('SCOTTY', 'M', 'Chihuahua', 'Queens', 11434),
#  ('CHAMP', 'M', 'Unknown', 'Queens', 11420),
#  ('BACARID', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('KOBE ', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('BRUTUS', 'M', 'West High White Terrier', 'Queens', 11419),
#  ('RESSIE', 'F', 'Yorkshire Terrier', 'Queens', 11419),
#  ('TOBEE', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('SNOOP', 'M', 'American Staffordshire Terrier ', 'Queens', 11691),
#  ('KARMA', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('BAILEY', 'F', 'Poodle, Standard', 'Queens', 11420),
#  ('NALA ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('RUBY ', 'F', 'Poodle, Standard', 'Queens', 11418),
#  ('BOSCO', 'M', 'Poodle, Standard', 'Queens', 11420),
#  ('TRINITY ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11417),
#  ('SHEBA ', 'F', 'Shih Tzu', 'Queens', 11692),
#  ('SCOUT', 'M', 'German Shepherd Dog', 'Queens', 11416),
#  ('JEAN-RALPHIO', 'M', 'Jack Russell Terrier', 'Queens', 11436),
#  ('JEETER', 'M', 'Maltese', 'Queens', 11416),
#  ('KING', 'M', 'Unknown', 'Queens', 11435),
#  ('LEO', 'M', 'Shih Tzu', 'Queens', 11692),
#  ('AVA', 'F', 'Maltese', 'Queens', 11692),
#  ('EVA', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11420),
#  ('CAMEO', 'F', 'Dalmatian', 'Queens', 11418),
#  ('MURPHY', 'M', 'Newfoundland', 'Queens', 11419),
#  ('SCOOBY', 'M', 'Staffordshire Bull Terrier', 'Queens', 11420),
#  ('BETSY ', 'F', 'Chihuahua', 'Queens', 11691),
#  ('RUFFO ', 'M', 'Poodle', 'Queens', 11433),
#  ('PEBBLES', 'F', 'Pomeranian', 'Queens', 11418),
#  ('BUDDY', 'M', 'Pomeranian', 'Queens', 11418),
#  ('SNOWY ', 'M', 'Unknown', 'Queens', 11434),
#  ('KHLOE', 'F', 'Shih Tzu Crossbreed', 'Queens', 11693),
#  ('SHADOW', 'M', 'Shih Tzu Crossbreed', 'Queens', 11419),
#  ('TOMMY', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('REESES', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('ROSIE ', 'F', 'German Shepherd Crossbreed', 'Queens', 11419),
#  ('SHELBY', 'F', 'German Shepherd Crossbreed', 'Queens', 11418),
#  ('TENESSEE', 'M', 'Beagle', 'Queens', 11422),
#  ('PRECIOUS ', 'F', 'Pomeranian', 'Queens', 11419),
#  ('MILO', 'M', 'Chihuahua Crossbreed', 'Queens', 11419),
#  ('LELA', 'F', 'Miniature Pinscher', 'Queens', 11420),
#  ('UNKNOWN', 'M', 'Shih Tzu', 'Queens', 11433),
#  ('T.O. ', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('BRUCE', 'M', 'Beagle', 'Queens', 11419),
#  ('MARCUS', 'M', 'Unknown', 'Queens', 11434),
#  ('MAE-LING', 'F', 'Shih Tzu', 'Queens', 11692),
#  ('CLYDE', 'M', 'German Shorthaired Pointer', 'Queens', 11418),
#  ('BANDIT', 'M', 'Shih Tzu', 'Queens', 11420),
#  ('BUGIE', 'M', 'Shih Tzu', 'Queens', 11416),
#  ('BORIS ', 'M', 'Siberian Husky', 'Queens', 11421),
#  ('BREEZY ', 'M', 'Maltese', 'Queens', 11691),
#  ('SHADOW', 'M', 'Pomeranian', 'Queens', 11413),
#  ('SHEBA ', 'F', 'Shih Tzu', 'Queens', 11692),
#  ('STORM', 'F', 'Miniature Schnauzer', 'Queens', 11421),
#  ('REBECCA', 'F', 'Shih Tzu', 'Queens', 11418),
#  ('NIKKI', 'F', 'West High White Terrier', 'Queens', 11417),
#  ('MURPHY', 'M', 'Boxer', 'Queens', 11692),
#  ('JETHEO', 'M', 'Unknown', 'Queens', 11693),
#  ('UNKNOWN', 'F', 'Shih Tzu', 'Queens', 11694),
#  ('CHLOE ', 'F', 'Yorkshire Terrier', 'Queens', 11417),
#  ('CHARLIE', 'F', 'Shih Tzu', 'Queens', 11420),
#  ('TAFFY', 'F', 'Shih Tzu', 'Queens', 11434),
#  ('CHULII ', 'F', 'Jack Russell Terrier', 'Queens', 11436),
#  ('INDIA', 'F', 'Poodle, Miniature', 'Queens', 11691),
#  ('NAME NOT PROVIDED', 'M', 'Yorkshire Terrier', 'Queens', 11419),
#  ('CHEWBACCA', 'M', 'Pomeranian', 'Queens', 11419),
#  ('SMOKEY', 'M', 'Unknown', 'Queens', 11418),
#  ('TEDDY', 'M', 'Pug', 'Queens', 11421),
#  ('K-AIYAH ', 'M', 'Labrador Retriever', 'Queens', 11420),
#  ('LAYLA ', 'F', 'Unknown', 'Queens', 11428),
#  ('SUNSHINE', 'F', 'Shih Tzu', 'Queens', 11420),
#  ('FIFI ', 'F', 'German Shepherd Dog', 'Queens', 11419),
#  ('LILY ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ("KINGG' ", 'M', 'Shih Tzu', 'Queens', 11434),
#  ('PRINCESS', 'F', 'Havanese', 'Queens', 11413),
#  ('SHEBA', 'F', 'Shih Tzu', 'Queens', 11692),
#  ('NAME NOT PROVIDED', 'M', 'Poodle Crossbreed', 'Queens', 11692),
#  ('DAISY', 'F', 'Chihuahua', 'Queens', 11436),
#  ('PHONIX', 'M', 'Maltese Crossbreed', 'Queens', 11434),
#  ('PAIGER', 'F', 'Unknown', 'Queens', 11418),
#  ('BROOKLYN', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11420),
#  ('PRIMO ', 'M', 'Pomeranian', 'Queens', 11691),
#  ('PRIMO ', 'M', 'Pomeranian', 'Queens', 11691),
#  ('MAC', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11419),
#  ('DREAMY', 'M', 'Yorkshire Terrier', 'Queens', 11418),
#  ('MARLIE', 'F', 'Cocker Spaniel', 'Queens', 11418),
#  ('CHASE', 'M', 'Chihuahua', 'Queens', 11420),
#  ('TRACY', 'F', 'Chihuahua', 'Queens', 11419),
#  ('BUSTER ', 'M', 'Unknown', 'Queens', 11417),
#  ('XENA', 'F', 'Bull Dog, English', 'Queens', 11416),
#  ('TOBY ', 'M', 'Shih Tzu', 'Queens', 11419),
#  ('MJ ', 'F', 'Chihuahua', 'Queens', 11692),
#  ('COOKIE', 'F', 'Shih Tzu', 'Queens', 11691),
#  ('CESAR', 'M', 'Rottweiler', 'Queens', 11691),
#  ('MISS ', 'F', 'American Bully', 'Queens', 11693),
#  ('LANDON', 'M', 'Chihuahua Crossbreed', 'Queens', 11421),
#  ('JADE ', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11693),
#  ('ANNA ', 'F', 'German Shepherd Dog', 'Queens', 11419),
#  ('MIA', 'F', 'Yorkshire Terrier', 'Queens', 11436),
#  ('COCO', 'F', 'Labrador Retriever Crossbreed', 'Queens', 11420),
#  ('BOBY', 'M', 'Puggle', 'Queens', 11418),
#  ('PRINCESS', 'F', 'Chihuahua', 'Queens', 11416),
#  ('CHIPPY ', 'M', 'Yorkshire Terrier', 'Queens', 11691),
#  ('HEIDI', 'F', 'Bassett Hound', 'Queens', 11417),
#  ('HAZELNUT', 'F', 'Chihuahua Crossbreed', 'Queens', 11693),
#  ('MIKEY', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('COOKIE', 'M', 'Cavalier King Charles Spaniel', 'Queens', 11418),
#  ('DIVA', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11435),
#  ('BELLA ', 'F', 'Yorkshire Terrier Crossbreed', 'Queens', 11434),
#  ('GIBBS ', 'M', 'Rottweiler', 'Queens', 11691),
#  ('CHUCKLES', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('BENTLEY', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('MAXAMIS ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11691),
#  ('PRINCE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11433),
#  ('CHEECH ', 'M', 'Chihuahua', 'Queens', 11434),
#  ('SCOOBY ', 'M', 'Havanese', 'Queens', 11420),
#  ('RAJAH ', 'M', 'Yorkshire Terrier', 'Queens', 11419),
#  ('BLAZE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11434),
#  ('MARLEY ', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('PRECIOUS ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11420),
#  ('CHARLIE', 'M', 'Rat Terrier', 'Queens', 11436),
#  ('PHOENIX ', 'F', 'Pug', 'Queens', 11420),
#  ('OCEANA ', 'F', 'Labrador Retriever', 'Queens', 11420),
#  ('RUBY', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11420),
#  ('APOLLO', 'M', 'Poodle Crossbreed', 'Queens', 11434),
#  ('COCO', 'F', 'Yorkshire Terrier', 'Queens', 11692),
#  ('OSCAR', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11691),
#  ('PHEONA', 'F', 'Schnauzer, Miniature', 'Queens', 11413),
#  ('CUPID', 'M', 'Beagle', 'Queens', 11420),
#  ('ROCCO', 'M', 'German Shepherd Crossbreed', 'Queens', 11416),
#  ('BONNIE', 'F', 'Cane Corso', 'Queens', 11434),
#  ('PRINCE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11422),
#  ('CLYDE', 'M', 'Cane Corso', 'Queens', 11434),
#  ('CHEEKY', 'F', 'Puggle', 'Queens', 11436),
#  ('KYLEE', 'F', 'Pomeranian', 'Queens', 11420),
#  ('NINO', 'M', 'Yorkshire Terrier', 'Queens', 11422),
#  ('ROSETTA', 'F', 'Yorkshire Terrier', 'Queens', 11418),
#  ('YUPYUP', 'M', 'Terrier mix', 'Queens', 11692),
#  ('BOBBY', 'M', 'Chihuahua', 'Queens', 11419),
#  ('MI ', 'F', 'Yorkshire Terrier Crossbreed', 'Queens', 11693),
#  ('ANNIE', 'F', 'Unknown', 'Queens', 11419),
#  ('BENTLEY', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11691),
#  ('CHANCE', 'M', 'Boston Terrier', 'Queens', 11420),
#  ('KIKI ', 'F', 'Poodle Crossbreed', 'Queens', 11434),
#  ('ATTICUS', 'M', 'Puggle', 'Queens', 11692),
#  ('OREO', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11418),
#  ('FOREST', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11418),
#  ('REX', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('BENJI', 'M', 'Maltese Crossbreed', 'Queens', 11692),
#  ('LUKE ', 'M', 'Siberian Husky', 'Queens', 11420),
#  ('JASPER', 'M', 'Australian Shepherd', 'Queens', 11418),
#  ('ONYX', 'M', 'Rottweiler', 'Queens', 11418),
#  ('KINKACHU ', 'F', 'Yorkshire Terrier', 'Queens', 11692),
#  ('TINA', 'F', 'Yorkshire Terrier Crossbreed', 'Queens', 11691),
#  ('PRINCESS ', 'F', 'Chihuahua', 'Queens', 11691),
#  ('SCOOBY', 'M', 'Unknown', 'Queens', 11435),
#  ('COOPER', 'M', 'German Shepherd Crossbreed', 'Queens', 11419),
#  ('PERCY ', 'M', 'Shih Tzu', 'Queens', 11416),
#  ('FLIGHT', 'M', 'Pomeranian', 'Queens', 11692),
#  ('DAISY ', 'F', 'American Staffordshire Terrier ', 'Queens', 11420),
#  ('NAYNAY', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('IVY', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11413),
#  ('JERRY', 'M', 'Labrador Retriever', 'Queens', 11436),
#  ('COCO', 'M', 'Unknown', 'Queens', 11418),
#  ('PRECIOUS', 'M', 'Yorkshire Terrier', 'Queens', 11419),
#  ('OAKLEY ', 'M', 'Doberman Pinscher', 'Queens', 11435),
#  ('BOSCO', 'M', 'Yorkshire Terrier', 'Queens', 11413),
#  ('MÍA ', 'F', 'Silky Terrier', 'Queens', 11419),
#  ('TONY', 'M', 'Beagle Crossbreed', 'Queens', 11434),
#  ('JAZZIE ', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('SAM', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11419),
#  ('CASPIAN', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('WINTER', 'F', 'Siberian Husky', 'Queens', 11435),
#  ('DAKOTA', 'F', 'Labrador Retriever', 'Queens', 11420),
#  ('DINKS ', 'M', 'Unknown', 'Queens', 11691),
#  ('NIKO', 'M', 'German Shepherd Dog', 'Queens', 11419),
#  ('NEO', 'M', 'Shiba Inu', 'Queens', 11420),
#  ("MAX'S ", 'M', 'Shih Tzu', 'Queens', 11434),
#  ('MAXIMILLIAN', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('CHARLIE', 'M', 'Miniature Pinscher', 'Queens', 11435),
#  ('HARLEY', 'M', 'Unknown', 'Queens', 11422),
#  ('BELLA ', 'F', 'Unknown', 'Queens', 11691),
#  ('GOTTI', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11422),
#  ('FLASH', 'M', 'Maltese', 'Queens', 11418),
#  ('NENA ', 'F', 'Unknown', 'Queens', 11692),
#  ('XANDY', 'F', 'German Shepherd Dog', 'Queens', 11420),
#  ('DIPSEY ', 'F', 'Toy Fox Terrier', 'Queens', 11436),
#  ('MEEKA', 'F', 'Yorkshire Terrier', 'Queens', 11141),
#  ('JUANCHO', 'M', 'Unknown', 'Queens', 11693),
#  ('PRINCESS', 'F', 'Maltese', 'Queens', 11434),
#  ('REX', 'M', 'Mastiff, Bull', 'Queens', 11691),
#  ('PUGSLEY', 'M', 'Pug', 'Queens', 11421),
#  ('CHICO', 'M', 'Pug', 'Queens', 11421),
#  ('MOOSE', 'M', 'Unknown', 'Queens', 11420),
#  ('LOUIE ', 'M', 'Shih Tzu', 'Queens', 11420),
#  ('SNOWY', 'F', 'American Eskimo dog', 'Queens', 11421),
#  ('SPEEDY', 'M', 'Chihuahua', 'Queens', 11421),
#  ('DAISY', 'F', 'Cavalier King Charles Spaniel', 'Queens', 11420),
#  ('ATHENA', 'F', 'German Shepherd Dog', 'Queens', 11419),
#  ('MAX', 'M', 'Boxer', 'Queens', 11419),
#  ('GINGER ', 'F', 'Unknown', 'Queens', 11416),
#  ('MAJOR', 'M', 'Shih Tzu', 'Queens', 11422),
#  ('SPARKY', 'M', 'Unknown', 'Queens', 11418),
#  ('CHELSEY', 'F', 'Yorkshire Terrier', 'Queens', 11419),
#  ('MOOCHIE', 'M', 'Unknown', 'Queens', 11413),
#  ('SUGAR', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11419),
#  ('SPOT', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11418),
#  ('CHLOE', 'F', 'Shih Tzu Crossbreed', 'Queens', 11419),
#  ('MIMI', 'F', 'Akita', 'Queens', 11420),
#  ('TODD', 'M', 'German Shepherd Dog', 'Queens', 11419),
#  ('BELLA', 'F', 'Yorkshire Terrier', 'Queens', 11420),
#  ('BLUE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('MILEY', 'F', 'Boxer', 'Queens', 11419),
#  ('BIJOU', 'M', 'Yorkshire Terrier', 'Queens', 11419),
#  ('MARLEY', 'M', 'Rottweiler', 'Queens', 11434),
#  ('U', 'M', 'Beagle', 'Queens', 11419),
#  ('JAX ', 'M', 'Yorkshire Terrier', 'Queens', 11418),
#  ('SNOOPY ', 'M', 'Maltese', 'Queens', 11413),
#  ('BENTLEY', 'M', 'Cocker Spaniel', 'Queens', 11435),
#  ('KODA', 'M', 'Bichon Frise', 'Queens', 11420),
#  ('LUCAS', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11420),
#  ('STITCH', 'M', 'Bichon Frise', 'Queens', 11420),
#  ('GOOBERS ', 'F', 'Cocker Spaniel', 'Queens', 11417),
#  ('BABIE ', 'F', 'Chihuahua', 'Queens', 11692),
#  ('KOBY', 'M', 'American Staffordshire Terrier ', 'Queens', 11418),
#  ('SPARTACUS', 'M', 'Maltese', 'Queens', 11419),
#  ('APHRODITE-ROSE', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11422),
#  ('NICKY', 'M', 'Silky Terrier', 'Queens', 11691),
#  ('MAX', 'M', 'Unknown', 'Queens', 11420),
#  ('BASIL', 'M', 'German Shepherd Crossbreed', 'Queens', 11691),
#  ('SHELA', 'F', 'Unknown', 'Queens', 11692),
#  ('MISSY', 'F', 'Mastiff, Bull', 'Queens', 11692),
#  ('JEAS', 'M', 'Shih Tzu', 'Queens', 11413),
#  ('TADDY', 'M', 'Poodle', 'Queens', 11693),
#  ('NELLY', 'F', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11436),
#  ('DANE', 'M', 'Poodle Crossbreed', 'Queens', 11422),
#  ('MICHAELA ', 'F', 'Havanese', 'Queens', 11419),
#  ('CHARLIE ', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11691),
#  ('JUJU', 'F', 'Yorkshire Terrier Crossbreed', 'Queens', 11691),
#  ('BONNIE', 'F', 'German Shepherd Dog', 'Queens', 11417),
#  ('MASON', 'M', 'Morkie', 'Queens', 11434),
#  ('MAX', 'M', 'Yorkshire Terrier', 'Queens', 11691),
#  ('BEANS', 'M', 'Beagle', 'Queens', 11436),
#  ('MACHO', 'M', 'Beagle', 'Queens', 11436),
#  ('JAX', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('CUPID', 'M', 'Labrador Retriever', 'Queens', 11436),
#  ('NAME NOT PROVIDED', 'F', 'Shih Tzu', 'Queens', 11434),
#  ('SCRAPPY', 'M', 'Shih Tzu', 'Queens', 11691),
#  ('PUTIE ', 'F', 'Shih Tzu', 'Queens', 11418),
#  ('NALA ', 'F', 'Boxer', 'Queens', 11418),
#  ('RILEY', 'M', 'Chihuahua Crossbreed', 'Queens', 11422),
#  ('PEBBLES', 'F', 'Unknown', 'Queens', 11422),
#  ('KC', 'M', 'Shih Tzu', 'Queens', 11416),
#  ('XOEY', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11691),
#  ('DAYLE', 'F', 'Unknown', 'Queens', 11422),
#  ('MILO', 'M', 'Shih Tzu', 'Queens', 11434),
#  ('SCOOBY', 'M', 'Unknown', 'Queens', 11417),
#  ('JAGUAR ', 'F', 'Unknown', 'Queens', 11413),
#  ('FROSTY ', 'M', 'West High White Terrier', 'Queens', 11692),
#  ('PEPPER', 'F', 'Beagle', 'Queens', 11418),
#  ('ARIES ', 'M', 'Unknown', 'Queens', 11420),
#  ('TYSON', 'M', 'Yorkshire Terrier', 'Queens', 11434),
#  ('BOWIE', 'M', 'Terrier mix', 'Queens', 11420),
#  ('KENJI ', 'M', 'German Shepherd Dog', 'Queens', 11422),
#  ('ROCKY', 'M', 'Unknown', 'Queens', 11420),
#  ('JESSICA', 'F', 'Cavalier King Charles Spaniel', 'Queens', 11416),
#  ('CHILLY', 'M', 'Chihuahua', 'Queens', 11691),
#  ('SHADOW', 'F', 'Unknown', 'Queens', 11422),
#  ('ANGEL', 'F', 'Shih Tzu', 'Queens', 11419),
#  ('MURRI ', 'M', 'Chihuahua', 'Queens', 11420),
#  ('DE ', 'F', 'German Shepherd Dog', 'Queens', 11434),
#  ('DENIM ', 'F', 'Poodle, Miniature', 'Queens', 11434),
#  ('MAX', 'M', 'Shih Tzu', 'Queens', 11416),
#  ('BELLA', 'F', 'Pomeranian', 'Queens', 11422),
#  ('PEBBLES', 'F', 'Chihuahua', 'Queens', 11435),
#  ('NAME NOT PROVIDED', 'M', 'Rottweiler', 'Queens', 11434),
#  ('BOSS', 'M', 'Yorkshire Terrier', 'Queens', 11692),
#  ('BLUE', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11433),
#  ('KOBE', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('AYUMI', 'F', 'Shiba Inu', 'Queens', 11420),
#  ('NAME NOT PROVIDED', 'M', 'Maltese Crossbreed', 'Queens', 11434),
#  ('MANGO', 'M', 'Pug', 'Queens', 11419),
#  ('GINGER', 'F', 'Unknown', 'Manhattan', 11419),
#  ('MAX', 'M', 'Unknown', 'Queens', 11421),
#  ('TRINKET', 'M', 'Yorkshire Terrier', 'Queens', 11691),
#  ('HARRY', 'M', 'Tibetan Terrier', 'Queens', 11422),
#  ('DOWNY ', 'M', 'Dachshund Smooth Coat', 'Queens', 11691),
#  ('DEXTER', 'M', 'Unknown', 'Queens', 11419),
#  ('GIZMO', 'M', 'Pug', 'Queens', 11421),
#  ('STORM', 'F', 'Cane Corso', 'Queens', 11434),
#  ('COOKIE', 'F', 'Maltipoo', 'Queens', 11420),
#  ('DIVA', 'F', 'Pomeranian', 'Queens', 11435),
#  ('ABBY', 'F', 'Dalmatian', 'Queens', 11420),
#  ('SOSSIE ', 'F', 'Shih Tzu', 'Queens', 11422),
#  ('OAKLEY', 'M', 'Cocker Spaniel', 'Queens', 11418),
#  ('KING', 'M', 'Maltese', 'Queens', 11422),
#  ('AVEN', 'M', 'Beagle Crossbreed', 'Queens', 11420),
#  ('NONI', 'M', 'Poodle, Standard', 'Queens', 11693),
#  ('CHIP', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('SHEBA', 'F', 'Shiba Inu', 'Queens', 11420),
#  ('KOBA', 'M', 'German Shepherd Dog', 'Queens', 11416),
#  ('CJ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Bronx', 11422),
#  ('AXEL', 'M', 'Boxer', 'Queens', 11419),
#  ('SWEETY ', 'F', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11434),
#  ('COCO', 'M', 'Yorkshire Terrier Crossbreed', 'Queens', 11417),
#  ('MIRACLE ', 'M', 'Havanese', 'Queens', 11434),
#  ('UNKNOWN', 'F', 'Chihuahua', 'Queens', 11434),
#  ('LOGAN', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11419),
#  ('SNOWBALL', 'M', 'Siberian Husky', 'Queens', 11420),
#  ('GARRITA', 'F', 'Chihuahua', 'Queens', 11418),
#  ('ALEX ', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11693),
#  ('MUFFIN', 'M', 'Chow Chow', 'Queens', 11435),
#  ('BENNY', 'M', 'Maltese', 'Queens', 11418),
#  ('SASHA ', 'F', 'Yorkshire Terrier', 'Queens', 11420),
#  ('HUNTER ', 'M', 'Beagle', 'Queens', 11418),
#  ('KHLOE', 'F', 'Yorkshire Terrier', 'Queens', 11692),
#  ('FRIDAY', 'M', 'Siberian Husky', 'Queens', 11434),
#  ('CHANELLY', 'F', 'Maltese', 'Queens', 11420),
#  ('COCO ', 'F', 'Chihuahua', 'Queens', 11434),
#  ('BERNIE', 'M', 'Poodle', 'Queens', 11419),
#  ('LUCY ', 'F', 'Cocker Spaniel', 'Queens', 11434),
#  ('TIGER', 'F', 'Staffordshire Bull Terrier', 'Queens', 11435),
#  ('ASTRO', 'M', 'Unknown', 'Queens', 11418),
#  ('MAX', 'M', 'Rottweiler', 'Queens', 11421),
#  ('JUSTICES ', 'F', 'Unknown', 'Queens', 11416),
#  ('FABIO', 'M', 'Siberian Husky', 'Queens', 11693),
#  ('CODY', 'M', 'Unknown', 'Queens', 11436),
#  ('DIEGO ', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11692),
#  ('SUPERMAN ', 'M', 'American Pit Bull Mix / Pit Bull Mix', 'Queens', 11693),
#  ('LOKI ', 'M', 'American Staffordshire Terrier ', 'Queens', 11691),
#  ('DIXIE-ROSE', 'F', 'Unknown', 'Queens', 11433),
#  ('NALA', 'F', 'Pug', 'Queens', 11420),
#  ('MOX ', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11418),
#  ('MAXWELL', 'M', 'Shih Tzu Crossbreed', 'Queens', 11434),
#  ('CHICHI', 'F', 'Pomeranian', 'Queens', 11434),
#  ('KODA', 'M', 'Cocker Spaniel', 'Queens', 11418),
#  ('ZOE', 'F', 'Silky Terrier', 'Queens', 11418),
#  ('OCEAN ', 'F', 'German Shepherd Dog', 'Queens', 11419),
#  ('TRUFFLE ', 'M', 'Yorkshire Terrier', 'Queens', 11420),
#  ('SHAGGY', 'M', 'Poodle, Miniature', 'Queens', 11416),
#  ('CHILLI', 'F', 'Miniature Pinscher', 'Queens', 11436),
#  ('PRINCIPIE ', 'M', 'Unknown', 'Queens', 11692),
#  ('TIP', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11692),
#  ('TITIANCRUBS', 'M', 'Labrador Retriever Crossbreed', 'Queens', 11420),
#  ('TARA', 'F', 'Golden Retriever', 'Queens', 11419),
#  ('FIDO', 'M', 'Miniature Pinscher', 'Queens', 11691),
#  ('LUCKY', 'M', 'Labrador Retriever', 'Queens', 11422),
#  ('SAGE ', 'M', 'Dachshund, Long Haired', 'Queens', 11691),
#  ('MIA-BELLA', 'F', 'Unknown', 'Queens', 11420),
#  ('KIHLOHLA ', 'F', 'American Staffordshire Terrier ', 'Queens', 11691),
#  ('MUGGLE', 'M', 'Lhasa Apso', 'Queens', 11435),
#  ('POLIE', 'M', 'Yorkshire Terrier', 'Queens', 11691),
#  ('LUCKY', 'M', 'Unknown', 'Queens', 11419),
#  ('SOCAL', 'M', 'Unknown', 'Queens', 11418),
#  ('ROCKY', 'M', 'Beagle Crossbreed', 'Queens', 11420),
#  ('KJ ', 'M', 'American Pit Bull Terrier/Pit Bull', 'Queens', 11434),
#  ('PELUCHE ', 'M', 'Shih Tzu', 'Queens', 11420),
#  ('BUTCH', 'M', 'Rottweiler', 'Queens', 11418),
#  ('TOMMY', 'M', 'Labrador Retriever', 'Queens', 11420),
#  ('IAN', 'M', 'Shih Tzu Crossbreed', 'Queens', 11691),
#  ('MOCHA ', 'F', 'American Bully', 'Queens', 11691),
#  ('LUNA', 'F', 'Poodle, Standard', 'Queens', 11418),
#  ('EMMA', 'F', 'Chesapeake Bay Retriever', 'Queens', 11692),
#  ('TEDDIE ', 'F', 'Yorkshire Terrier', 'Queens', 11436),
#  ('FLUFFY', 'F', 'Chow Chow', 'Queens', 11420),
#  ('BUDDY', 'M', 'Lhasa Apso', 'Queens', 11692),
#  ('BRETTA', 'F', 'American Staffordshire Terrier ', 'Queens', 11433),
#  ('NOODLES', 'M', 'Pomeranian', 'Queens', 11436),
#  ('CLEAPATRA', 'F', 'Pomeranian', 'Queens', 11435),
#  ('MAX ', 'M', 'German Shepherd Dog', 'Queens', 11413),
#  ('ROCCO', 'M', 'Shih Tzu', 'Queens', 11436),
#  ('BATMAN', 'M', 'Unknown', 'Queens', 11436),
#  ('GINGER', 'F', 'Shih Tzu', 'Queens', 11691),
#  ('FEMI', 'M', 'Shih Tzu', 'Queens', 11692),
#  ('ACE ', 'M', 'Maltese', 'Queens', 11434),
#  ('PORKY', 'M', 'Shih Tzu', 'Queens', 11420),
#  ('COCO', 'F', 'Chihuahua', 'Queens', 11419),
#  ('KOKITO', 'M', 'Shih Tzu Crossbreed', 'Queens', 11421),
#  ('SHADOW', 'M', 'Pomeranian', 'Queens', 11436),
#  ('SCRUFFY ', 'M', 'Shih Tzu', 'Queens', 11421),
#  ('BELLA', 'F', 'Chihuahua', 'Queens', 11418),
#  ('PRINCE ', 'M', 'Bichon Frise', 'Queens', 11419),
#  ('ZORRO', 'M', 'Unknown', 'Queens', 11418),
#  ...]

# %%
# inspect table names and column names

inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['dog_names']

# %%
inspector = inspect(engine)
columns = inspector.get_columns('dog_names')
print(columns)
# Out:
# [{'name': 'AnimalName', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'AnimalGender', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'BreedName', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'Borough', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'ZipCode', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}]

# %%
# query the table and save as dataframe for analysis

dog_table = pd.read_sql_query('select * from dog_names', con=engine)
dog_table.head(20)
# Out:
#    AnimalName AnimalGender                           BreedName Borough  \
# 0     BONITA             F                             Unknown  Queens
# 1       ROCKY            M       Labrador Retriever Crossbreed  Queens
# 2       BULLY            M  American Pit Bull Terrier/Pit Bull  Queens
# 3       COCO             M                  Labrador Retriever  Queens
# 4        SKI             F  American Pit Bull Terrier/Pit Bull  Queens
# 5       CHASE            M                            Shih Tzu  Queens
# 6      CHEWY             M                            Shih Tzu  Queens
# 7       CHASE            M                  Labrador Retriever  Queens
# 8       MILEY            F                               Boxer  Queens
# 9       KENZI            F                Schnauzer, Miniature  Queens
# 10    APOLLO             M  American Pit Bull Terrier/Pit Bull  Queens
# 11     BELLA             F                   Yorkshire Terrier  Queens
# 12  PENELOPE             F                   Yorkshire Terrier  Queens
# 13      JERRY            M                  Labrador Retriever  Queens
# 14      HAZEL            F  American Pit Bull Terrier/Pit Bull  Queens
# 15      SIMON            M                            Havanese  Queens
# 16   PRINCESS            F                            Shih Tzu  Queens
# 17     PEPPER            F                            Shih Tzu  Queens
# 18    PEBBLES            F                   Yorkshire Terrier  Queens
# 19      BUDDY            M       Labrador Retriever Crossbreed  Queens
#
#     ZipCode
# 0     11435
# 1     11691
# 2     11419
# 3     11692
# 4     11691
# 5     11692
# 6     11694
# 7     11691
# 8     11419
# 9     11420
# 10    11420
# 11    11434
# 12    11434
# 13    11436
# 14    11434
# 15    11691
# 16    11417
# 17    11417
# 18    11417
# 19    11692

# %%
dog_data = dog_table.loc[(dog_table["AnimalName"] != "UNKNOWN") & (dog_table["AnimalName"] != "NAME NOT PROVIDED"), :]
dog_data.head(20)
# Out:
#    AnimalName AnimalGender                           BreedName Borough  \
# 0     BONITA             F                             Unknown  Queens
# 1       ROCKY            M       Labrador Retriever Crossbreed  Queens
# 2       BULLY            M  American Pit Bull Terrier/Pit Bull  Queens
# 3       COCO             M                  Labrador Retriever  Queens
# 4        SKI             F  American Pit Bull Terrier/Pit Bull  Queens
# 5       CHASE            M                            Shih Tzu  Queens
# 6      CHEWY             M                            Shih Tzu  Queens
# 7       CHASE            M                  Labrador Retriever  Queens
# 8       MILEY            F                               Boxer  Queens
# 9       KENZI            F                Schnauzer, Miniature  Queens
# 10    APOLLO             M  American Pit Bull Terrier/Pit Bull  Queens
# 11     BELLA             F                   Yorkshire Terrier  Queens
# 12  PENELOPE             F                   Yorkshire Terrier  Queens
# 13      JERRY            M                  Labrador Retriever  Queens
# 14      HAZEL            F  American Pit Bull Terrier/Pit Bull  Queens
# 15      SIMON            M                            Havanese  Queens
# 16   PRINCESS            F                            Shih Tzu  Queens
# 17     PEPPER            F                            Shih Tzu  Queens
# 18    PEBBLES            F                   Yorkshire Terrier  Queens
# 19      BUDDY            M       Labrador Retriever Crossbreed  Queens
#
#     ZipCode
# 0     11435
# 1     11691
# 2     11419
# 3     11692
# 4     11691
# 5     11692
# 6     11694
# 7     11691
# 8     11419
# 9     11420
# 10    11420
# 11    11434
# 12    11434
# 13    11436
# 14    11434
# 15    11691
# 16    11417
# 17    11417
# 18    11417
# 19    11692

# %%
name_counts = pd.DataFrame(dog_data.groupby("AnimalName")["AnimalName"].count())
name_counts_df = name_counts.rename(columns={"AnimalName":"Count"})
name_counts_df.head()
# Out:
#             Count
# AnimalName
#   KNOX          1
#   PANDORA       1
#  BABIE JR.      1
#  BELLA          1
#  BELLE          2

# %%
top_names = name_counts_df.sort_values(["Count"], ascending=False)
top_names.head(12)
# Out:
#             Count
# AnimalName
# BELLA        1008
# MAX          1001
# CHARLIE       750
# LOLA          686
# ROCKY         668
# COCO          642
# LUCY          581
# BUDDY         559
# LUCKY         551
# DAISY         507
# LUNA          464
# BAILEY        429

# %%
f_dog_data = dog_data.loc[dog_data["AnimalGender"] == "F", :]
f_dog_data.head()
# Out:
#    AnimalName AnimalGender                           BreedName Borough  \
# 0     BONITA             F                             Unknown  Queens
# 4        SKI             F  American Pit Bull Terrier/Pit Bull  Queens
# 8       MILEY            F                               Boxer  Queens
# 9       KENZI            F                Schnauzer, Miniature  Queens
# 11     BELLA             F                   Yorkshire Terrier  Queens
#
#     ZipCode
# 0     11435
# 4     11691
# 8     11419
# 9     11420
# 11    11434

# %%
f_name_counts = pd.DataFrame(f_dog_data.groupby("AnimalName")["AnimalName"].count())
f_name_counts_df = f_name_counts.rename(columns={"AnimalName":"Count"})
f_top_names = f_name_counts_df.sort_values(["Count"], ascending=False)
f_top_names.head(12)
# Out:
#                    Count
# AnimalName
# UNKNOWN             1081
# BELLA               1006
# LOLA                 682
# NAME NOT PROVIDED    657
# LUCY                 578
# DAISY                503
# LUNA                 461
# COCO                 440
# PRINCESS             428
# CHLOE                416
# MOLLY                409
# BELLA                351

# %%
m_dog_data = dog_data.loc[dog_data["AnimalGender"] == "M", :]
m_name_counts = pd.DataFrame(m_dog_data.groupby("AnimalName")["AnimalName"].count())
m_name_counts_df = m_name_counts.rename(columns={"AnimalName":"Count"})
m_top_names = m_name_counts_df.sort_values(["Count"], ascending=False)
m_top_names.head(12)
# Out:
#                    Count
# AnimalName
# UNKNOWN             1386
# NAME NOT PROVIDED   1107
# MAX                  985
# CHARLIE              660
# ROCKY                658
# BUDDY                556
# LUCKY                467
# TOBY                 411
# TEDDY                408
# JACK                 347
# MILO                 345
# OLIVER               332

# %%
borough_counts = pd.DataFrame(dog_data.groupby("Borough")["AnimalName"].count())
borough_counts_df = borough_counts.rename(columns={"AnimalName":"Count"})
borough_dogs = borough_counts_df.sort_values(["Count"], ascending=False)
borough_dogs.head()
# Out:
#                Count
# Borough
# Manhattan      42344
# Brooklyn       30036
# Queens         24658
# Bronx          12485
# Staten Island  10873

# %%
top_boroughs = dog_data.loc[(dog_data["Borough"] == "Manhattan") | (dog_data["Borough"] == "Brooklyn") | (dog_data["Borough"] == "Queens") | (dog_data["Borough"] == "Bronx") | (dog_data["Borough"] == "Staten Island"), :]
f_m_top_boroughs = top_boroughs.loc[(top_boroughs["AnimalGender"] == "F") | (top_boroughs["AnimalGender"] == "M"), :]
f_m_top_boroughs.head()
# Out:
#   AnimalName AnimalGender                           BreedName Borough  ZipCode
# 0    BONITA             F                             Unknown  Queens    11435
# 1      ROCKY            M       Labrador Retriever Crossbreed  Queens    11691
# 2      BULLY            M  American Pit Bull Terrier/Pit Bull  Queens    11419
# 3      COCO             M                  Labrador Retriever  Queens    11692
# 4       SKI             F  American Pit Bull Terrier/Pit Bull  Queens    11691

# %%
borough_data = f_m_top_boroughs.groupby(['Borough','AnimalGender'])["AnimalName"].count()
borough_dogs = pd.DataFrame(borough_data)
borough_dogs
# Out:
#                             AnimalName
# Borough       AnimalGender
# Bronx         F                   5445
#               M                   7040
# Brooklyn      F                  13589
#               M                  16445
# Manhattan     F                  19679
#               M                  22663
# Queens        F                  10797
#               M                  13859
# Staten Island F                   4932
#               M                   5940

# %%
mt_dog_data = dog_data.loc[dog_data["Borough"].str.contains("Manhattan", case=False), :]
mt_name_counts = pd.DataFrame(mt_dog_data.groupby("AnimalName")["AnimalName"].count())
mt_name_counts_df = mt_name_counts.rename(columns={"AnimalName":"Count"})
mt_top_names = mt_name_counts_df.sort_values(["Count"], ascending=False)
mt_top_names.head(12)
# Out:
#                    Count
# AnimalName
# UNKNOWN              944
# NAME NOT PROVIDED    334
# CHARLIE              292
# LUCY                 288
# LOLA                 275
# BELLA                255
# MAX                  244
# COCO                 194
# OLIVER               193
# DAISY                185
# COOPER               167
# SOPHIE               167

# %%
bk_dog_data = dog_data.loc[dog_data["Borough"].str.contains("Brooklyn", case=False), :]
bk_name_counts = pd.DataFrame(bk_dog_data.groupby("AnimalName")["AnimalName"].count())
bk_name_counts_df = bk_name_counts.rename(columns={"AnimalName":"Count"})
bk_top_names = bk_name_counts_df.sort_values(["Count"], ascending=False)
bk_top_names.head(12)
# Out:
#                    Count
# AnimalName
# UNKNOWN              937
# NAME NOT PROVIDED    462
# MAX                  252
# BELLA                238
# CHARLIE              191
# LOLA                 164
# ROCKY                153
# LUCKY                148
# LUCY                 143
# COCO                 125
# PRINCESS             123
# CHLOE                119

# %%
qn_dog_data = dog_data.loc[dog_data["Borough"].str.contains("Queens", case=False), :]
qn_name_counts = pd.DataFrame(qn_dog_data.groupby("AnimalName")["AnimalName"].count())
qn_name_counts_df = qn_name_counts.rename(columns={"AnimalName":"Count"})
qn_top_names = qn_name_counts_df.sort_values(["Count"], ascending=False)
qn_top_names.head(12)
# Out:
#                    Count
# AnimalName
# NAME NOT PROVIDED    649
# UNKNOWN              333
# MAX                  260
# BELLA                229
# ROCKY                182
# COCO                 174
# LUCKY                156
# CHARLIE              144
# BUDDY                138
# LOLA                 115
# PRINCESS             110
# DAISY                108

# %%
bx_dog_data = dog_data.loc[dog_data["Borough"].str.contains("Bronx", case=False), :]
bx_name_counts = pd.DataFrame(bx_dog_data.groupby("AnimalName")["AnimalName"].count())
bx_name_counts_df = bx_name_counts.rename(columns={"AnimalName":"Count"})
bx_top_names = bx_name_counts_df.sort_values(["Count"], ascending=False)
bx_top_names.head(12)
# Out:
#                    Count
# AnimalName
# NAME NOT PROVIDED    161
# MAX                  138
# BELLA                126
# UNKNOWN              122
# ROCKY                109
# PRINCESS              94
# LUCKY                 91
# COCO                  82
# LOLA                  74
# CHARLIE               67
# TOBY                  64
# BUDDY                 59

# %%
si_dog_data = dog_data.loc[dog_data["Borough"].str.contains("Staten Island", case=False), :]
si_name_counts = pd.DataFrame(si_dog_data.groupby("AnimalName")["AnimalName"].count())
si_name_counts_df = si_name_counts.rename(columns={"AnimalName":"Count"})
si_top_names = si_name_counts_df.sort_values(["Count"], ascending=False)
si_top_names.head(12)
# Out:
#                    Count
# AnimalName
# BELLA                159
# NAME NOT PROVIDED    156
# UNKNOWN              131
# MAX                  104
# ROCKY                100
# BUDDY                 80
# BAILEY                75
# MOLLY                 65
# COCO                  63
# CHARLIE               56
# DAISY                 53
# LOLA                  52
